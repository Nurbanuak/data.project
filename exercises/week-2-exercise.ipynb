# %%
import pandas as pd

base_url = "C:/Users/victus/Documents/data.project/data/covid/"
infected_dataset_url =  "C:/Users/victus/Documents/data.project/data/covid/time_series_covid19_confirmed_global.csv"
recovered_dataset_url = "C:/Users/victus/Documents/data.project/data/covid/time_series_covid19_recovered_global.csv"
deaths_dataset_url = "C:/Users/victus/Documents/data.project/data/covid/time_series_covid19_deaths_global.csv"

# %%
infected_df = pd.read_csv("C:/Users/victus/Documents/data.project/data/covid/time_series_covid19_confirmed_global.csv")
recovered_df = pd.read_csv("C:/Users/victus/Documents/data.project/data/covid/time_series_covid19_recovered_global.csv")
deaths_df = pd.read_csv("C:/Users/victus/Documents/data.project/data/covid/time_series_covid19_deaths_global.csv")

# %%
print("\nInfected Dataset Overview:")
print(infected_df.head())

print("\nRecovered Dataset Overview:")
print(recovered_df.head())

print("\nDeaths Dataset Overview:")
print(deaths_df.head())
# Out:
# Infected Dataset Overview:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...   19551   20342   20917   21459    22142
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
# 3        0        0        0  ...     852     852     852     852      852
# 4        0        0        0  ...      88      91      92      96      113
#
# ...

# %%
grouped_infected = infected_df.groupby('Country/Region').sum().iloc[:, 4:]
grouped_recovered = recovered_df.groupby('Country/Region').sum().iloc[:, 4:]
grouped_deaths = deaths_df.groupby('Country/Region').sum().iloc[:, 4:]

# %%
print("\nGrouped Infected Data:")
print(grouped_infected.head())

print("\nGrouped Recovered Data:")
print(grouped_recovered.head())

print("\nGrouped Deaths Data:")
print(grouped_deaths.head())
# Out:
# Grouped Infected Data:
#                 1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/30/20  1/31/20  2/1/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# Country/Region                            ...
# Afghanistan           0        0       0  ...   19551   20342   20917   21459
# Albania               0        0       0  ...    1232    1246    1263    1299
# Algeria               0        0       0  ...   10050   10154   10265   10382
# Andorra               0        0       0  ...     852     852     852     852
# ...
