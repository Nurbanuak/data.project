# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv("C:/Users/victus/Documents/data.project/week-1/sales_data.csv",
   parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    Revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %%
sales.shape
# Out:
# (113036, 18)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
#  16  Cost              113036 non-null  int64
#  17  Revenue           113036 non-null  int64
# dtypes: datetime64[ns](1), int64(9), object(8)
# memory usage: 15.5+ MB

# %%
sales.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# 25%         2.000000       5.000000      29.000000      28.000000
# 50%         9.000000      24.000000     101.000000     108.000000
# 75%        42.000000      70.000000     358.000000     432.000000
# max      2171.000000    3578.000000   15096.000000   42978.000000
#
#              Revenue
# count  113036.000000
# mean      754.370360
# std      1309.094674
# min         2.000000
# 25%        63.000000
# 50%       223.000000
# 75%       800.000000
# max     58074.000000

# %%
sales['Unit_Cost'].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %%
sales['Unit_Cost'].mean()
# Out:
# 267.296365759581

# %%
sales['Unit_Cost'].median()
# Out:
# 9.0

# %%
sales['Unit_Cost'].plot(kind='box', vert=False, figsize=(10,6))
# Out:
# <AxesSubplot: >

# %%
sales['Unit_Cost'].plot(kind='density', figsize=(10,6))
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
ax = sales['Unit_Cost'].plot(kind='density', figsize=(10,6))
ax.axvline(sales['Unit_Cost'].mean(), color='red')
ax.axvline(sales['Unit_Cost'].median(), color='green')

# %%
ax = sales['Unit_Cost'].plot(kind='hist', figsize=(10,6))
ax.set_ylabel('Number of Sales')
ax.set_xlabel('dollars')
# Out:
# Text(0.5, 0, 'dollars')

# %%
sales['Age_Group'].value_counts()
# Out:
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: Age_Group, dtype: int64

# %%
sales['Age_Group'].value_counts().plot(kind='pie', figsize=(8,8))
# Out:
# <AxesSubplot: ylabel='Age_Group'>

# %%
ax = sales['Age_Group'].value_counts().plot(kind='bar', figsize=(10,6))
ax.set_ylabel('Number of Sales')
# Out:
# Text(0, 0.5, 'Number of Sales')

# %%
sales_corr = sales[["Day", "Year", "Customer_Age", "Order_Quantity", "Unit_Cost", "Unit_Price", "Profit", "Cost", "Revenue"]]
sales_corr.head()
# Out:
#    Day  Year  Customer_Age  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 0   26  2013            19               8         45         120     590
# 1   26  2015            19               8         45         120     590
# 2   23  2014            49              23         45         120    1366
# 3   23  2016            49              20         45         120    1188
# 4   15  2014            47               4         45         120     238
#
#    Cost  Revenue
# 0   360      950
# 1   360      950
# 2  1035     2401
# 3   900     2088
# 4   180      418

# %%
corr = sales_corr.corr()
corr
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# Customer_Age     -0.020262  0.004319 -0.016013 -0.009326
# Order_Quantity   -0.515925 -0.238863 -0.340382 -0.312895
# Unit_Cost         0.997894  0.741020  0.829869  0.817865
# Unit_Price        1.000000  0.749870  0.826301  0.818522
# Profit            0.749870  1.000000  0.902233  0.956572
# Cost              0.826301  0.902233  1.000000  0.988758
# Revenue           0.818522  0.956572  0.988758  1.000000

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
sales.plot(kind='scatter', x='Customer_Age', y='Revenue', figsize=(10,6))
# Out:
# <AxesSubplot: xlabel='Customer_Age', ylabel='Revenue'>

# %%
sales.plot(kind='scatter', x='Revenue', y='Profit', figsize=(10,6))
# Out:
# <AxesSubplot: xlabel='Revenue', ylabel='Profit'>

# %%
ax = sales[['Profit', 'Age_Group']].boxplot(by='Age_Group', figsize=(10,6))
ax.set_ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
boxplot_cols = ['Year', 'Customer_Age', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit']

sales[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(12,8))
# Out:
# Year                 AxesSubplot(0.125,0.53;0.227941x0.35)
# Customer_Age      AxesSubplot(0.398529,0.53;0.227941x0.35)
# Order_Quantity    AxesSubplot(0.672059,0.53;0.227941x0.35)
# Unit_Cost            AxesSubplot(0.125,0.11;0.227941x0.35)
# Unit_Price        AxesSubplot(0.398529,0.11;0.227941x0.35)
# Profit            AxesSubplot(0.672059,0.11;0.227941x0.35)
# dtype: object

# %%
sales['Revenue_per_Age'] = sales['Revenue'] / sales['Customer_Age']

# %%
sales['Revenue_per_Age'].head()
# Out:
# 0    50.000000
# 1    50.000000
# 2    49.000000
# 3    42.612245
# 4     8.893617
# Name: Revenue_per_Age, dtype: float64

# %%
sales['Revenue_per_Age'].plot(kind='density', figsize=(10,6))
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
sales['Revenue_per_Age'].plot(kind='hist', figsize=(10,6))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
sales['Calculated_Cost'] = sales['Order_Quantity'] * sales['Unit_Cost']

# %%
(sales['Calculated_Cost'] != sales['Cost']).sum()
# Out:
# 0

# %%
sales.plot(kind='scatter', x='Calculated_Cost', y='Profit', figsize=(10,6))
# Out:
# <AxesSubplot: xlabel='Calculated_Cost', ylabel='Profit'>

# %%
sales['Unit_Price'].head()
# Out:
# 0    120
# 1    120
# 2    120
# 3    120
# 4    120
# Name: Unit_Price, dtype: int64

# %%
sales['Unit_Price'] *= 1.03
sales['Unit_Price'].head()
# Out:
# 0    123.6
# 1    123.6
# 2    123.6
# 3    123.6
# 4    123.6
# Name: Unit_Price, dtype: float64

# %%
sales.loc[sales["Country"] == "Germany"]
# Out:
#              Date  Day      Month  Year  Customer_Age             Age_Group  \
# 48     2013-08-07    7     August  2013            38        Adults (35-64)
# 49     2015-08-07    7     August  2015            38        Adults (35-64)
# 62     2013-09-25   25  September  2013            19           Youth (<25)
# 63     2015-09-25   25  September  2015            19           Youth (<25)
# 94     2013-09-23   23  September  2013            41        Adults (35-64)
# ...           ...  ...        ...   ...           ...                   ...
# 113007 2016-03-28   28      March  2016            28  Young Adults (25-34)
# 113010 2014-04-10   10      April  2014            25  Young Adults (25-34)
# 113011 2016-04-10   10      April  2016            25  Young Adults (25-34)
# 113026 2013-07-08    8       July  2013            29  Young Adults (25-34)
# 113027 2015-07-08    8       July  2015            29  Young Adults (25-34)
#
#        Customer_Gender  Country     State Product_Category Sub_Category  \
# 48                   M  Germany  Saarland      Accessories   Bike Racks
# 49                   M  Germany  Saarland      Accessories   Bike Racks
# 62                   F  Germany  Saarland      Accessories   Bike Racks
# 63                   F  Germany  Saarland      Accessories   Bike Racks
# 94                   F  Germany    Hessen      Accessories   Bike Racks
# ...                ...      ...       ...              ...          ...
# 113007               F  Germany  Saarland         Clothing        Vests
# 113010               M  Germany   Hamburg         Clothing        Vests
# 113011               M  Germany   Hamburg         Clothing        Vests
# 113026               M  Germany    Hessen         Clothing        Vests
# 113027               M  Germany    Hessen         Clothing        Vests
#
#                     Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 48      Hitch Rack - 4-Bike               3         45      123.60     160
# 49      Hitch Rack - 4-Bike               1         45      123.60      53
# 62      Hitch Rack - 4-Bike               6         45      123.60     320
# 63      Hitch Rack - 4-Bike               8         45      123.60     427
# 94      Hitch Rack - 4-Bike              28         45      123.60    1865
# ...                     ...             ...        ...         ...     ...
# 113007      Classic Vest, L               5         24       65.92     142
# 113010      Classic Vest, S              28         24       65.92     995
# 113011      Classic Vest, S              28         24       65.92     995
# 113026      Classic Vest, L              20         24       65.92     710
# 113027      Classic Vest, L              21         24       65.92     746
#
#         Cost  Revenue  Revenue_per_Age  Calculated_Cost
# 48       135      295         7.763158              135
# 49        45       98         2.578947               45
# 62       270      590        31.052632              270
# 63       360      787        41.421053              360
# 94      1260     3125        76.219512             1260
# ...      ...      ...              ...              ...
# 113007   120      262         9.357143              120
# 113010   672     1667        66.680000              672
# 113011   672     1667        66.680000              672
# 113026   480     1190        41.034483              480
# 113027   504     1250        43.103448              504
#
# [11098 rows x 20 columns]

# %%
sales.loc[(sales['Age_Group'] == 'Adults (35-64)') & (sales['Country'] == 'United States'), 'Revenue'].mean()
# Out:
# 726.7260473588342
